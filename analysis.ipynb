# %%
# Import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Setup pandas
pd.set_option('display.max_columns', None)

# %%
# Get the current working directory
os.getcwd()
# Out:
# '/Users/ahmadyusufalbadri/Documents/1 - Learning/4 - Competition/datavidia 2025/Datavidia'

# %%
# Import data
df = pd.read_csv('data/train.csv')
df.sample(5)
# Out:
#       Unnamed: 0      Negara/Tahun  Emisi Savanna Api  Emisi Kebakaran Hutan  \
# 2518        2518  Isle of Man/2000             0.0021                 0.0224
# 4546        4546   Seychelles/2002             0.0000                 0.0000
# 4880        4880  Switzerland/2013             0.0000                 0.0000
# 3259        3259      Mayotte/2010             0.0000                 0.0000
# 575          575       Bhutan/1996             0.7866                18.1561
#
#       Emisi Residu Tanaman  Emisi Budidaya Padi  \
# 2518                   NaN           926.342278
# 4546                   NaN           921.664109
# 4880               50.5331           495.646742
# 3259                   NaN          1746.105511
# 575                11.4621            96.567300
#
#       Emisi Tanah Organik Yang Dikeringkan (Co2)  Emisi Pembuatan Pestisida  \
# 2518                                     20.4330                  11.481085
# ...

# %%
# Remove the first column and add 2 columns for negara and tahun
df[['Negara', 'Tahun']] = df['Negara/Tahun'].str.split('/', expand=True)
df = df.iloc[:, 2:]
df.sample(5)
# Out:
#       Emisi Savanna Api  Emisi Kebakaran Hutan  Emisi Residu Tanaman  \
# 1320            52.6404                57.2901               44.0167
# 3259             0.0000                 0.0000                   NaN
# 667          11123.1473             12184.1197             3854.2338
# 1042           313.4201               838.1820            23891.3751
# 444              0.0000                 0.0000                0.0192
#
#       Emisi Budidaya Padi  Emisi Tanah Organik Yang Dikeringkan (Co2)  \
# 1320          1212.848000                                      0.0000
# 3259          1746.105511                                      0.0000
# 667           7178.555500                                    339.8606
# 1042        164915.255600                                   3701.2430
# 444            246.407276                                      0.0000
#
#       Emisi Pembuatan Pestisida  Emisi Transportasi Makanan  Lahan Hutan  \
# ...

# %%
# Quick check on duplicated data and missing values
print('The number of duplicated rows:', df.duplicated().sum(), '\n')
print('Missing values check:')
print(df.isna().sum())
# Out:
# The number of duplicated rows: 0
#
# Missing values check:
# Emisi Savanna Api                                25
# Emisi Kebakaran Hutan                            75
# Emisi Residu Tanaman                           1118
# Emisi Budidaya Padi                               0
# Emisi Tanah Organik Yang Dikeringkan (Co2)        0
# Emisi Pembuatan Pestisida                         0
# Emisi Transportasi Makanan                        0
# Lahan Hutan                                     397
# Konversi Hutan Bersih                           397
# Emisi Konsumsi Rumah Tangga Makanan             389
# Emisi Ritel Makanan                               0
# Emisi Penggunaan Listrik Di Pertanian             0
# Emisi Kemasan Makanan                             0
# Emisi Sistem Agrifood Pembuangan Limbah           0
# Emisi Pengolahan Makanan                          0
# Emisi Manufaktur Pupuk                            0
# Emisi IPPU                                      599
# ...
